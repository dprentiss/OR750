# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# %run project.py

# %%
num_meters = 96
input_dim = num_meters
hidden_dim = 96
batch_dim = 1
output_dim = 96 * 4
num_layers = 2
learning_rate = 0.01
num_epochs = 100

# %%
ami = pd.read_csv('./data/ami-uniq.txt', sep='\t')
ami['datetime'] = pd.to_datetime(ami['datetime'], format='%Y-%m-%d %H:%M:%S')
#weather = pd.read_csv('./data/WeatherData_Zipcode_77088.csv')
#weather = weather.drop(columns=['LocalDateTime', 'TimeZone'])

# %%
#ami.loc[ami['id']==81].plot(y='kw', figsize=(30,6))

# %%
series_kw = ami.pivot(index='id', columns='datetime', values='kw')

# %%
#series_kw.count().unique()

# %%
t_0 = series_kw.loc[:,series_kw.count() > 82].columns[0]
t_f = series_kw.loc[:,series_kw.count() > 82].columns[-1]
kw_part = series_kw.loc[:,t_0:t_f].fillna(0)
kw_x_norm = (kw_part - kw_part.mean().mean()) / (kw_part.max().max() - kw_part.min().min())
kw_sum = kw_part.sum() / kw_part.count() * num_meters
kw_y_norm = (kw_sum - kw_sum.mean()) / (kw_sum.max() - kw_sum.min())

# %%
#kw_y_norm.plot(figsize=(100,5))

# %%
X_train = torch.tensor(kw_x_norm.transpose().values).float()
X_train = X_train.view([-1, 1, input_dim])
y_train = torch.tensor(kw_y_norm).float()
y_train = y_train.unfold(0, 96*4, 1)
#y_train.size()

# %%
model = AmiTest(input_dim, hidden_dim, batch_dim, output_dim, num_layers)
loss_fn = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
hist = np.zeros(num_epochs)

# %%
model.hidden = model.init_hidden()

# %%
for t in range(num_epochs):
    model.hidden = model.init_hidden()
    y_pred = model(X_train)
    loss = loss_fn(y_pred[0:y_train.size(0),0], y_train)
    if t % 1 == 0:
        print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch  0 MSE:  174894.8125
# Epoch  1 MSE:  159974.640625
# Epoch  2 MSE:  148956.5
# Epoch  3 MSE:  134684.96875
# Epoch  4 MSE:  126345.3515625
# Epoch  5 MSE:  128031.015625
# Epoch  6 MSE:  123143.4453125
# Epoch  7 MSE:  124986.4296875
# Epoch  8 MSE:  118512.1171875
# Epoch  9 MSE:  114425.671875
# Epoch  10 MSE:  102352.34375
# Epoch  11 MSE:  119331.9453125
# Epoch  12 MSE:  120962.140625
# Epoch  13 MSE:  101517.3203125
# Epoch  14 MSE:  103163.8984375
# Epoch  15 MSE:  106359.65625
# Epoch  16 MSE:  105430.34375
# Epoch  17 MSE:  101557.03125
# Epoch  18 MSE:  97901.71875
# Epoch  19 MSE:  92959.828125
# Epoch  20 MSE:  85952.5
# Epoch  21 MSE:  80819.9765625
# Epoch  22 MSE:  77594.375
# Epoch  23 MSE:  72007.4140625
# Epoch  24 MSE:  70893.7890625
# Epoch  25 MSE:  61985.81640625
# Epoch  26 MSE:  61245.60546875
# Epoch  27 MSE:  63478.1953125
# Epoch  28 MSE:  61231.05078125
# Epoch  29 MSE:  58851.15625
# Epoch  30 MSE:  58123.71875
# Epoch  31 MSE:  57082.390625
# Epoch  32 MSE:  55903.06640625
# Epoch  33 MSE:  54945.90625
# Epoch  34 MSE:  54583.0859375
# Epoch  35 MSE:  54234.65625
# Epoch  36 MSE:  53485.9609375
# Epoch  37 MSE:  52080.41796875
# Epoch  38 MSE:  50607.62109375
# Epoch  39 MSE:  50348.078125
# Epoch  40 MSE:  50332.81640625
# Epoch  41 MSE:  49628.08984375
# Epoch  42 MSE:  49136.6953125
# Epoch  43 MSE:  48767.328125
# Epoch  44 MSE:  48251.390625
# Epoch  45 MSE:  48096.43359375
# Epoch  46 MSE:  47704.40625
# Epoch  47 MSE:  47105.16796875
# Epoch  48 MSE:  46859.2890625
# Epoch  49 MSE:  46434.23828125
# Epoch  50 MSE:  46305.10546875
# Epoch  51 MSE:  46417.12890625
# Epoch  52 MSE:  46272.82421875
# Epoch  53 MSE:  45869.98828125
# Epoch  54 MSE:  45518.41796875
# Epoch  55 MSE:  45110.31640625
# Epoch  56 MSE:  44474.01171875
# Epoch  57 MSE:  44508.68359375
# Epoch  58 MSE:  44698.30859375
# Epoch  59 MSE:  44174.70703125
# Epoch  60 MSE:  43649.59765625
# Epoch  61 MSE:  43338.5078125
# Epoch  62 MSE:  43266.76171875
# Epoch  63 MSE:  43236.29296875
# Epoch  64 MSE:  42949.73046875
# Epoch  65 MSE:  42648.98828125
# Epoch  66 MSE:  42333.45703125
# Epoch  67 MSE:  42095.55859375
# Epoch  68 MSE:  42064.66015625
# Epoch  69 MSE:  42160.16015625
# Epoch  70 MSE:  43035.046875
# Epoch  71 MSE:  43588.64453125
# Epoch  72 MSE:  45710.9453125
# Epoch  73 MSE:  41562.66015625
# Epoch  74 MSE:  45264.55078125
# Epoch  75 MSE:  46998.4921875
# Epoch  76 MSE:  42565.84765625
# Epoch  77 MSE:  46243.5859375
# Epoch  78 MSE:  40781.15625
# Epoch  79 MSE:  43930.19921875
# Epoch  80 MSE:  40460.8359375
# Epoch  81 MSE:  42862.65234375
# Epoch  82 MSE:  40249.01953125
# Epoch  83 MSE:  41516.0078125
# Epoch  84 MSE:  40385.94921875
# Epoch  85 MSE:  40149.40625
# Epoch  86 MSE:  40542.1875
# Epoch  87 MSE:  39402.26953125
# Epoch  88 MSE:  40452.609375
# Epoch  89 MSE:  39153.66015625
# Epoch  90 MSE:  39848.578125
# Epoch  91 MSE:  38807.78125
# Epoch  92 MSE:  39053.0
# Epoch  93 MSE:  38633.91796875
# Epoch  94 MSE:  38475.0625
# Epoch  95 MSE:  38469.31640625
# Epoch  96 MSE:  38097.625
# Epoch  97 MSE:  38953.41796875
# Epoch  98 MSE:  39267.40625
# Epoch  99 MSE:  37952.0703125

# %%
t = 0
plt.plot(y_pred[0:y_train.size(0),0][t].detach().numpy(), label="pred")
plt.plot(y_train[t].detach().numpy(), label="data")
plt.legend()
plt.show()

# %%
t = 9384
plt.plot(y_pred[0:y_train.size(0),0][t].detach().numpy(), label="pred")
plt.plot(y_train[t].detach().numpy(), label="data")
plt.legend()
plt.show()

# %%
plt.plot(hist)
