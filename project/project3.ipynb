# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# %run project.py

# %%
num_meters = 96
input_dim = num_meters
hidden_dim = 96
batch_dim = 1
output_dim = 96 * 4
num_layers = 3
learning_rate = 0.01
num_epochs = 100

# %%
ami = pd.read_csv('./data/ami-uniq.txt', sep='\t')
ami['datetime'] = pd.to_datetime(ami['datetime'], format='%Y-%m-%d %H:%M:%S')
#weather = pd.read_csv('./data/WeatherData_Zipcode_77088.csv')
#weather = weather.drop(columns=['LocalDateTime', 'TimeZone'])

# %%
#ami.loc[ami['id']==81].plot(y='kw', figsize=(30,6))

# %%
series_kw = ami.pivot(index='id', columns='datetime', values='kw')

# %%
#series_kw.count().unique()

# %%
t_0 = series_kw.loc[:,series_kw.count() > 82].columns[0]
t_f = series_kw.loc[:,series_kw.count() > 82].columns[-1]
kw_part = series_kw.loc[:,t_0:t_f].fillna(0)
kw_x_norm = kw_part / (kw_part.max().max() - kw_part.min().min())
kw_sum = kw_part.sum() / kw_part.count() * num_meters
kw_y_norm = kw_sum / (kw_sum.max() - kw_sum.min())

# %%
#kw_y_norm.plot(figsize=(100,5))

# %%
X_train = torch.tensor(kw_x_norm.transpose().values).float()
X_train = X_train.view([-1, 1, input_dim])
y_train = torch.tensor(kw_y_norm).float()
y_train = y_train.unfold(0, 96*4, 1)
#y_train.size()

# %%
model = AmiTest(input_dim, hidden_dim, batch_dim, output_dim, num_layers)
loss_fn = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
hist = np.zeros(num_epochs)

# %%
model.hidden = model.init_hidden()

# %%
for t in range(num_epochs):
    model.hidden = model.init_hidden()
    y_pred = model(X_train)
    loss = loss_fn(y_pred[0:y_train.size(0),0], y_train)
    if t % 1 == 0:
        print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch  0 MSE:  755367.25
# Epoch  1 MSE:  615559.875
# Epoch  2 MSE:  326452.75
# Epoch  3 MSE:  366965.875
# Epoch  4 MSE:  290909.4375
# Epoch  5 MSE:  187630.59375
# Epoch  6 MSE:  253628.875
# Epoch  7 MSE:  191397.046875
# Epoch  8 MSE:  166173.828125
# Epoch  9 MSE:  172743.234375
# Epoch  10 MSE:  175273.75
# Epoch  11 MSE:  168650.0
# Epoch  12 MSE:  160216.203125
# Epoch  13 MSE:  157594.5
# Epoch  14 MSE:  161960.21875
# Epoch  15 MSE:  165534.125
# Epoch  16 MSE:  161397.4375
# Epoch  17 MSE:  153333.359375
# Epoch  18 MSE:  147479.796875
# Epoch  19 MSE:  145067.140625
# Epoch  20 MSE:  143734.359375
# Epoch  21 MSE:  140585.65625
# Epoch  22 MSE:  135420.078125
# Epoch  23 MSE:  133339.71875
# Epoch  24 MSE:  135702.515625
# Epoch  25 MSE:  130437.8828125
# Epoch  26 MSE:  132931.828125
# Epoch  27 MSE:  125483.203125
# Epoch  28 MSE:  126049.7109375
# Epoch  29 MSE:  125986.8203125
# Epoch  30 MSE:  122942.2734375
# Epoch  31 MSE:  121645.3203125
# Epoch  32 MSE:  121437.421875
# Epoch  33 MSE:  117727.15625
# Epoch  34 MSE:  119392.6953125
# Epoch  35 MSE:  117613.015625
# Epoch  36 MSE:  116470.109375
# Epoch  37 MSE:  118005.0859375
# Epoch  38 MSE:  115857.609375
# Epoch  39 MSE:  114078.9453125
# Epoch  40 MSE:  113239.6875
# Epoch  41 MSE:  111528.5703125
# Epoch  42 MSE:  110525.8125
# Epoch  43 MSE:  110367.28125
# Epoch  44 MSE:  109076.9765625
# Epoch  45 MSE:  108307.875
# Epoch  46 MSE:  107975.8984375
# Epoch  47 MSE:  107473.3671875
# Epoch  48 MSE:  105696.9375
# Epoch  49 MSE:  107376.3515625
# Epoch  50 MSE:  104911.9375
# Epoch  51 MSE:  105829.6953125
# Epoch  52 MSE:  112725.21875
# Epoch  53 MSE:  108245.828125
# Epoch  54 MSE:  102804.3671875
# Epoch  55 MSE:  100331.90625
# Epoch  56 MSE:  102643.5625
# Epoch  57 MSE:  101521.921875
# Epoch  58 MSE:  95615.46875
# Epoch  59 MSE:  94966.421875
# Epoch  60 MSE:  97785.375
# Epoch  61 MSE:  94057.875
# Epoch  62 MSE:  89823.59375
# Epoch  63 MSE:  88481.3671875
# Epoch  64 MSE:  88723.3203125
# Epoch  65 MSE:  86664.953125
# Epoch  66 MSE:  102445.5546875
# Epoch  67 MSE:  131088.828125
# Epoch  68 MSE:  121804.1875
# Epoch  69 MSE:  107313.984375
# Epoch  70 MSE:  105056.4453125
# Epoch  71 MSE:  108000.3671875
# Epoch  72 MSE:  110304.015625
# Epoch  73 MSE:  110509.7890625
# Epoch  74 MSE:  109011.2890625
# Epoch  75 MSE:  106162.703125
# Epoch  76 MSE:  102971.734375
# Epoch  77 MSE:  98309.8515625
# Epoch  78 MSE:  93681.6328125
# Epoch  79 MSE:  89911.671875
# Epoch  80 MSE:  86955.3671875
# Epoch  81 MSE:  84195.4296875
# Epoch  82 MSE:  80805.1015625
# Epoch  83 MSE:  77921.65625
# Epoch  84 MSE:  75119.9765625
# Epoch  85 MSE:  74079.40625
# Epoch  86 MSE:  75885.109375
# Epoch  87 MSE:  71016.9453125
# Epoch  88 MSE:  67678.1796875
# Epoch  89 MSE:  66715.0
# Epoch  90 MSE:  69156.234375
# Epoch  91 MSE:  75384.1640625
# Epoch  92 MSE:  72002.59375
# Epoch  93 MSE:  66776.9296875
# Epoch  94 MSE:  70762.1015625
# Epoch  95 MSE:  67123.953125
# Epoch  96 MSE:  65097.74609375
# Epoch  97 MSE:  64574.16015625
# Epoch  98 MSE:  63096.39453125
# Epoch  99 MSE:  61467.56640625

# %%
t = 0
plt.plot(y_pred[0:y_train.size(0),0][t].detach().numpy(), label="pred")
plt.plot(y_train[t].detach().numpy(), label="data")
plt.legend()
plt.show()

# %%
t = 1384
plt.plot(y_pred[0:y_train.size(0),0][t].detach().numpy(), label="pred")
plt.plot(y_train[t].detach().numpy(), label="data")
plt.legend()
plt.show()

# %%
plt.plot(hist)
