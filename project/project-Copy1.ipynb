# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# %run project.py

# %%
num_meters = 96
input_dim = num_meters
hidden_dim = 96
batch_dim = 1
output_dim = 96 * 4
num_layers = 2
learning_rate = 0.01
num_epochs = 100

# %%
ami = pd.read_csv('./data/ami-uniq.txt', sep='\t')
ami['datetime'] = pd.to_datetime(ami['datetime'], format='%Y-%m-%d %H:%M:%S')
#weather = pd.read_csv('./data/WeatherData_Zipcode_77088.csv')
#weather = weather.drop(columns=['LocalDateTime', 'TimeZone'])

# %%
ami.loc[ami['id']==3].plot(y='kw', figsize=(10,6))

# %%
ami.loc[ami['id']==19].iloc[0:348].plot(y='kw')

# %%
plt.figure(figsize=(10,6))
plt.plot(series_kw.iloc[19,0:384])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(kw_sum.iloc[0:384])
plt.show()

# %%
series_kw = ami.pivot(index='id', columns='datetime', values='kw')

# %%
#series_kw.count().unique()

# %%
t_0 = series_kw.loc[:,series_kw.count() > 82].columns[0]
t_f = series_kw.loc[:,series_kw.count() > 82].columns[-1]
kw_part = series_kw.loc[:,t_0:t_f].fillna(0)
kw_x_norm = kw_part / (kw_part.max().max() - kw_part.min().min())
kw_sum = kw_part.sum() / kw_part.count() * num_meters
kw_y_norm = kw_sum / (kw_sum.max() - kw_sum.min())

# %%
#kw_y_norm.plot(figsize=(100,5))

# %%
X_train = torch.tensor(kw_x_norm.transpose().values).float()
X_train = X_train.view([-1, 1, input_dim])
y_train = torch.tensor(kw_y_norm).float()
y_train = y_train.unfold(0, 96*4, 1)
#y_train.size()

# %%
model = AmiTest(input_dim, hidden_dim, batch_dim, output_dim, num_layers)
loss_fn = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
hist = np.zeros(num_epochs)

# %%
model.hidden = model.init_hidden()

# %%
for t in range(num_epochs):
    model.hidden = model.init_hidden()
    y_pred = model(X_train)
    loss = loss_fn(y_pred[0:y_train.size(0),0], y_train)
    if t % 1 == 0:
        print("Epoch ", t, "MSE: ", loss.item())
    hist[t] = loss.item()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch  0 MSE:  775820.5625
# Epoch  1 MSE:  647730.8125
# Epoch  2 MSE:  269263.8125
# Epoch  3 MSE:  1476125.375
# Epoch  4 MSE:  257712.203125
# Epoch  5 MSE:  246631.96875
# Epoch  6 MSE:  318238.03125
# Epoch  7 MSE:  299622.3125
# Epoch  8 MSE:  261375.609375
# Epoch  9 MSE:  227346.390625
# Epoch  10 MSE:  203097.546875
# Epoch  11 MSE:  193861.265625
# Epoch  12 MSE:  196695.6875
# Epoch  13 MSE:  181886.953125
# Epoch  14 MSE:  164037.9375
# Epoch  15 MSE:  159362.1875
# Epoch  16 MSE:  165051.796875
# Epoch  17 MSE:  172210.875
# Epoch  18 MSE:  175043.28125
# Epoch  19 MSE:  172295.8125
# Epoch  20 MSE:  165870.015625
# Epoch  21 MSE:  158995.25
# Epoch  22 MSE:  154565.984375
# Epoch  23 MSE:  153234.109375
# Epoch  24 MSE:  152769.78125
# Epoch  25 MSE:  151346.90625
# Epoch  26 MSE:  149406.234375
# Epoch  27 MSE:  145812.171875
# Epoch  28 MSE:  139149.765625
# Epoch  29 MSE:  135209.0
# Epoch  30 MSE:  130112.0703125
# Epoch  31 MSE:  132482.046875
# Epoch  32 MSE:  130463.7890625
# Epoch  33 MSE:  129577.3046875
# Epoch  34 MSE:  126154.9375
# Epoch  35 MSE:  123765.40625
# Epoch  36 MSE:  123325.46875
# Epoch  37 MSE:  122103.359375
# Epoch  38 MSE:  122053.3359375
# Epoch  39 MSE:  122013.53125
# Epoch  40 MSE:  121123.3984375
# Epoch  41 MSE:  120872.578125
# Epoch  42 MSE:  120555.6015625
# Epoch  43 MSE:  119732.7265625
# Epoch  44 MSE:  119631.59375
# Epoch  45 MSE:  119302.5703125
# Epoch  46 MSE:  118809.9375
# Epoch  47 MSE:  118672.5625
# Epoch  48 MSE:  117983.5703125
# Epoch  49 MSE:  117391.265625
# Epoch  50 MSE:  117016.953125
# Epoch  51 MSE:  116383.8515625
# Epoch  52 MSE:  115943.078125
# Epoch  53 MSE:  115433.15625
# Epoch  54 MSE:  114489.5390625
# Epoch  55 MSE:  113370.8125
# Epoch  56 MSE:  111908.984375
# Epoch  57 MSE:  110894.546875
# Epoch  58 MSE:  108524.3515625
# Epoch  59 MSE:  106516.5234375
# Epoch  60 MSE:  108667.09375
# Epoch  61 MSE:  112925.75
# Epoch  62 MSE:  114522.4453125
# Epoch  63 MSE:  112934.1875
# Epoch  64 MSE:  113347.5078125
# Epoch  65 MSE:  110899.578125
# Epoch  66 MSE:  104113.859375
# Epoch  67 MSE:  103266.25
# Epoch  68 MSE:  98852.84375
# Epoch  69 MSE:  97343.046875
# Epoch  70 MSE:  95162.7109375
# Epoch  71 MSE:  94598.484375
# Epoch  72 MSE:  92232.7109375
# Epoch  73 MSE:  91668.4609375
# Epoch  74 MSE:  90752.5703125
# Epoch  75 MSE:  90436.8203125
# Epoch  76 MSE:  88901.109375
# Epoch  77 MSE:  87375.5390625
# Epoch  78 MSE:  86738.0625
# Epoch  79 MSE:  85868.5625
# Epoch  80 MSE:  84692.734375
# Epoch  81 MSE:  85803.328125
# Epoch  82 MSE:  84026.078125
# Epoch  83 MSE:  83397.515625
# Epoch  84 MSE:  83113.0078125
# Epoch  85 MSE:  82481.578125
# Epoch  86 MSE:  82334.5625
# Epoch  87 MSE:  82735.6484375
# Epoch  88 MSE:  82237.9609375
# Epoch  89 MSE:  82047.78125
# Epoch  90 MSE:  81816.8671875
# Epoch  91 MSE:  81284.1484375
# Epoch  92 MSE:  80933.6953125
# Epoch  93 MSE:  80861.4453125
# Epoch  94 MSE:  80595.5390625
# Epoch  95 MSE:  80317.9296875
# Epoch  96 MSE:  80331.328125
# Epoch  97 MSE:  79843.9375
# Epoch  98 MSE:  79630.296875
# Epoch  99 MSE:  79406.0234375

# %%
t = 0
plt.plot(y_pred[0:y_train.size(0),0][t].detach().numpy(), label="pred")
plt.plot(y_train[t].detach().numpy(), label="data")
plt.legend()
plt.show()

# %%
t = 3384
plt.plot(y_pred[0:y_train.size(0),0][t].detach().numpy(), label="pred")
plt.plot(y_train[t].detach().numpy(), label="data")
plt.legend()
plt.show()

# %%
plt.plot(hist)
